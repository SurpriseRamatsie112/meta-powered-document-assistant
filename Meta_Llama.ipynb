# %%
# %pip install -q \
  llama-index \
  llama-index-llms-openrouter \
  llama-index-embeddings-huggingface \
  llama-index-readers-file \
  llama-index-packs-fusion-retriever \
  sentence-transformers \
  nest-asyncio \
  requests

print("✅ Installation complete")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 103.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.3/303.3 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.3/683.3 kB 39.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 10.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ✅ Installation complete

# %%
import os
from getpass import getpass
import nest_asyncio

nest_asyncio.apply()

from llama_index.core import Settings
from llama_index.llms.openrouter import OpenRouter
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Ask for your OpenRouter API key (input is hidden like a password)
os.environ["OPENROUTER_API_KEY"] = getpass("Enter your OpenRouter API key: ")

# Configure the LLM (Meta Llama via OpenRouter)
llm = OpenRouter(
    api_key=os.environ["OPENROUTER_API_KEY"],
    model="meta-llama/llama-3.3-70b-instruct:free",
    max_tokens=512,
    temperature=0.1,  # Low = more precise, less “creative”
    timeout=60,
    system_prompt=(
        "You are an expert RAG system that answers ONLY using the provided context. "
        "Never hallucinate. Never guess. If the answer is not in the context, say so. "
        "Provide short, clear, factual responses with 2–4 evidence bullets."
    ),
)

# Configure the embedding model
embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

# Register both with LlamaIndex settings
Settings.llm = llm
Settings.embed_model = embed_model

print("✅ AI model and settings are ready to use")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Enter your OpenRouter API key: ··········
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ AI model and settings are ready to use

# %%
import os
import re
import requests

def download_pdf_from_drive(drive_url: str, save_path: str):
    """
    Download a PDF from a Google Drive sharing link and save it locally.
    """
    # Try pattern: /d/<FILE_ID>/
    match = re.search(r"/d/([A-Za-z0-9_-]+)", drive_url)
    if match:
        file_id = match.group(1)
    else:
        # Try pattern: ?id=<FILE_ID>
        match = re.search(r"id=([A-Za-z0-9_-]+)", drive_url)
        if match:
            file_id = match.group(1)
        else:
            raise ValueError("❌ Could not extract file ID from the link.")

    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
    print(f"📥 Downloading PDF (file ID {file_id})...")

    resp = requests.get(download_url)
    resp.raise_for_status()

    with open(save_path, "wb") as f:
        f.write(resp.content)

    print(f"✅ PDF downloaded → {save_path}")

# Ask for the Drive link
drive_link = input("📌 Paste your Google Drive PDF link here: ").strip()

# Make sure the data folder exists
DATA_DIR = "data"
os.makedirs(DATA_DIR, exist_ok=True)

# Local path for the PDF
pdf_path = os.path.join(DATA_DIR, "source.pdf")

# Download the PDF
download_pdf_from_drive(drive_link, pdf_path)
# Out:
# 📌 Paste your Google Drive PDF link here: https://drive.google.com/file/d/1UGcRXCDixtvbC2K_dfeU6ijfzJga88GR/view
# 📥 Downloading PDF (file ID 1UGcRXCDixtvbC2K_dfeU6ijfzJga88GR)...
# ✅ PDF downloaded → data/source.pdf

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SemanticSplitterNodeParser
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Load the PDF as a document
documents = SimpleDirectoryReader(input_files=[pdf_path]).load_data()
print(f"📄 Loaded {len(documents)} document(s).")

# Embedding model for semantic splitting (can reuse the same model name)
semantic_embed = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# Create a semantic splitter
parser = SemanticSplitterNodeParser(
    buffer_size=3,
    breakpoint_percentile_threshold=95,
    embed_model=semantic_embed,
)

# Generate semantic nodes (chunks)
nodes = parser.get_nodes_from_documents(documents)

# Add simple metadata to each chunk
for n in nodes:
    n.metadata["source"] = pdf_path
    n.metadata["chunk_type"] = "semantic"

print(f"🔍 Created {len(nodes)} high-quality semantic nodes.")
# Out:
# 📄 Loaded 3 document(s).
# 🔍 Created 4 high-quality semantic nodes.

# %%
from llama_index.core.llama_pack import download_llama_pack

# Download or load the Query Fusion pack
QueryRewritingRetrieverPack = download_llama_pack(
    "QueryRewritingRetrieverPack",
    "./query_rewriting_pack",
)

# Create the advanced retriever using your nodes
query_rewriting_pack = QueryRewritingRetrieverPack(
    nodes,                      # semantic chunks from Step 4
    chunk_size=256,
    vector_similarity_top_k=8,
    fusion_similarity_top_k=8,
    num_queries=6,              # number of query rewrites
)

print("🚀 Advanced Query Fusion RAG Engine Ready!")
# Out:
# 🚀 Advanced Query Fusion RAG Engine Ready!

# %%
def safe_rag_run(question, retries=3):
    """
    Run the RAG pipeline with basic retry logic.
    """
    for attempt in range(retries):
        try:
            resp = query_rewriting_pack.run(question)

            if resp is None or str(resp).strip() == "":
                raise ValueError("Empty LLM response.")

            return resp

        except Exception as e:
            print(f"⚠️ Error: {e}")
            print(f"🔁 Retrying ({attempt+1}/{retries})...")

    return "❌ Could not generate a valid answer after retries."

print("\nRAG Interactive Mode")
print("Ask any question about your PDF.")
print("Type 'end' to exit.\n")

# Interactive Q&A loop
while True:
    user_question = input("🟦 Enter your question: ").strip()

    if user_question.lower() == "end":
        print("\n👋 Session ended.")
        break

    print("\n🔍 Retrieving answer...\n")

    # Run the question through the RAG pipeline
    response = safe_rag_run(user_question)

    print("\n──────────────────────────────────────────────")
    print("❓ QUESTION:")
    print(user_question)
    print("\n🧠 ANSWER:")
    print(response)
    print("──────────────────────────────────────────────\n")
# Out:
# RAG Interactive Mode
# Ask any question about your PDF.
# Type 'end' to exit.
#
# 🟦 Enter your question: what is the main goal of this document?
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What is the primary objective of this document?
# What is the main purpose of this text?
# What is the central idea of this document?
# What is the key takeaway from this document?
# What is the intended outcome of reading this document?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# what is the main goal of this document?
#
# 🧠 ANSWER:
# The main goal of this document is to showcase the skills, experience, and education of a software developer.
# * It highlights their technical skills, including programming languages and development tools.
# * It showcases their experience in software development projects and as a tech trainer.
# * It presents their professional summary, showcasing their motivation and passion for delivering high-quality software solutions.
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: summarise the key points of this document
#
# 🔍 Retrieving answer...
#
# Generated queries:
# What are the main points of the document that need to be summarized?
# How can I create a concise summary of the document's key points?
# What tools or techniques can be used to effectively summarize a long document?
# What are the most important details that should be included in a summary of the document?
# How can I identify and extract the key points from a complex document to create a clear and concise summary?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# summarise the key points of this document
#
# 🧠 ANSWER:
# * The document appears to be a resume or CV, highlighting the skills and experience of a software developer.
# * Key technical skills include programming languages such as Python and Java, development tools like Git and IntelliJ, and testing frameworks.
# * The developer has experience with various projects, including a banking system, code clinics, and a to-do list app.
# * They also have experience as a tech trainer, delivering AI and digital training, and conducting digital systems audits.
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: does this document imply that the candidate is ready for work opportunities ?
#
# 🔍 Retrieving answer...
#
# Generated queries:
# Does the document provide evidence of the candidate's job readiness and preparedness for work opportunities?
# What specific skills or qualifications mentioned in the document suggest the candidate is ready for work opportunities?
# Are there any statements or phrases in the document that explicitly indicate the candidate's readiness for employment or work opportunities?
# How does the document portray the candidate's level of experience and training in relation to their readiness for work opportunities?
# What keywords or phrases in the document can be used to determine the candidate's readiness for work opportunities, such as "job ready" or "employable skills"?
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# does this document imply that the candidate is ready for work opportunities ?
#
# 🧠 ANSWER:
# Yes, the document implies that the candidate is ready for work opportunities.
# * The candidate has hands-on experience in Python and Java.
# * They have experience with version control, development, and automation tools like Git, GitLab, GitHub, and Bash.
# * They have a portfolio of projects, including Python and Java projects, demonstrating their skills.
# * The candidate's professional summary states that they are a "Motivated software developer" looking to contribute to a technical team.
# ──────────────────────────────────────────────
#
# 🟦 Enter your question: thank you
#
# 🔍 Retrieving answer...
#
# Generated queries:
# How to express gratitude in different languages
# Ways to say thank you in a romantic relationship
# Quotes about appreciation and thankfulness
# Gift ideas to show thanks to a friend or family member
# Phrases to use when writing a thank you note or email
#
# ──────────────────────────────────────────────
# ❓ QUESTION:
# thank you
#
# 🧠 ANSWER:
# You're welcome.
#
# * No specific information is provided to respond to "thank you".
# * The context appears to be a resume or CV for a software developer.
# * It includes technical skills, experience, and education.
# * There is no direct response to the query "thank you" in the context.
# ──────────────────────────────────────────────
